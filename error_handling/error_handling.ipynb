# %% [markdown]
# Error handling is the art of anticipating disasters so your program doesn't "crash and burn" when something goes wrong. In Python, we use the try-except block.

# %%
try:
    # Code that might fail
    amount = int(input("Enter withdrawal amount: "))
    result = 1000 / amount
except ValueError:
    # Runs if user types "abc" instead of a number
    print("Error: Please enter a valid number!")
except ZeroDivisionError:
    # Runs if user types "0"
    print("Error: You cannot divide by zero!")
except Exception as e:
    # The "Catch-all" for any other unexpected errors
    print(f"Something else went wrong: {e}")
# Out:
# Error: Please enter a valid number!

# %% [markdown]
# Handling a File Read

# %%
try:
    file = open("data.txt", "r")
    content = file.read()
except FileNotFoundError:
    print("Oops! That file doesn't exist.")
else:
    print("File read successfully!")
    print(content)
finally:
    print("Closing resources...")
    # This ensures the file isn't left hanging open in memory
    if 'file' in locals():
        file.close()
# Out:
# File read successfully!
# hi macha
# Closing resources...
